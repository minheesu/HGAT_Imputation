# %% [markdown]
# ### VS code 연동

# %%
# !pip install colab_ssh --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared 
launch_ssh_cloudflared(password="dkagh12#$")
# Out:
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...

# %% [markdown]
# ### Github connection

# %%
import pandas as pd

# google drive mount
from google.colab import drive
drive.mount('/content/drive')

#import h5py
#data = h5py.File('/content/drive/MyDrive/samsung_project/datasets/AirQuality/small36.h5', 'r')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
git_token = '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'
git_user = 'minheesu'
git_repo = 'HGAT_Imputation'
git_path = 'https://' + git_token + '@github.com/' + git_user + '/' + git_repo + '.git'
print(git_path)

# github와 연동하고 싶은 폴더로 이동
from os.path import join
#proj_path = '/content/drive/MyDrive/github'
proj_path = '/content/drive/MyDrive/github/HGAT_Imputation'
# %cd '{proj_path}'
#!git clone '{git_path}'
# Out:
# https://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@github.com/minheesu/HGAT_Imputation.git
# /content/drive/MyDrive/github/HGAT_Imputation

# %%
# git 생성
# !git init
# !git config --global user.email 'nn151009@gmail.com'
# !git config --global user.name 'minheesu'
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/github/HGAT_Imputation/.git/

# %%
# !git status
# Out:
# On branch main
# All conflicts fixed but you are still merging.
#   (use "git commit" to conclude merge)
#
# Changes to be committed:
#
# 	deleted:    test2.txt
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	test.ipynb

# %%
# commit log check
# !git log

# %%
# 원격 저장소 연결 상태 확인 
# !git remote -v
# Out:
# orgin	https://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@github.com/minheesu/HGAT_Imputation.git (fetch)
# orgin	https://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@github.com/minheesu/HGAT_Imputation.git (push)

# %%
# 원격 저장소 재연결
# !git remote add orgin https://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@github.com/minheesu/HGAT_Imputation.git

# %%
# !git remote rm orgin

# %%
# !git remote update
# Out:
# Fetching orgin
# From https://github.com/minheesu/HGAT_Imputation
#  * [new branch]      main          -> orgin/main
#  * [new branch]      revert-5-test -> orgin/revert-5-test
#  * [new branch]      test_         -> orgin/test_

# %%
# !git reset HEAD^
# Out:
# Unstaged changes after reset:
# M	README.md
# D	test2.txt

# %%
# file add
#!git add test.ipynb
#!echo "# 2022.10.11 hs-test" >> README.md
#!echo "# HGAT_Imputation" > README.md
#!git add README.md
# !git add /content/drive/MyDrive/github/HGAT_Imputation/grin/lib/datasets/__init__.py

# %%
# commit
# !git commit -m "hs test3 commit"
# Out:
# [main 0aebba0] hs test3 commit
#  1 file changed, 1 insertion(+)

# %%
# !git push orgin
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 494 bytes | 247.00 KiB/s, done.
# Total 6 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# remote:
# remote: GitHub found 524 vulnerabilities on minheesu/HGAT_Imputation's default branch (7 critical, 128 high, 304 moderate, 85 low). To find out more, visit:
# remote:      https://github.com/minheesu/HGAT_Imputation/security/dependabot
# remote:
# To https://github.com/minheesu/HGAT_Imputation.git
#    10189e6..0aebba0  main -> main

# %%
# !git push --set-upstream orgin main
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 614 bytes | 102.00 KiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 1 local object.
# remote:
# remote: GitHub found 524 vulnerabilities on minheesu/HGAT_Imputation's default branch (7 critical, 128 high, 304 moderate, 85 low). To find out more, visit:
# remote:      https://github.com/minheesu/HGAT_Imputation/security/dependabot
# remote:
# To https://github.com/minheesu/HGAT_Imputation.git
#    f05e0b9..9711864  main -> main
# Branch 'main' set up to track remote branch 'main' from 'orgin'.

# %%
# !git branch -M main

# %%
# !git pull orgin
# Out:
# From https://github.com/minheesu/HGAT_Imputation
#  * [new branch]      revert-5-test -> orgin/revert-5-test
#  * [new branch]      test_         -> orgin/test_
# Already up to date.
